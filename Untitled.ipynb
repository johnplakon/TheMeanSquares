# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

# %%
data_path = 'vgsales-12-4-2019.csv'

# %%
#Read csv with table
vg_df =pd.read_csv(data_path, header=0)
df = vg_df[vg_df.notnull()]
df.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# ...

# %%
#groupby by head
df.groupby(df['ESRB_Rating']).head()
# Out:
#         Rank                                               Name  \
# 0          1                                         Wii Sports
# 1          2                                  Super Mario Bros.
# 2          3                                     Mario Kart Wii
# 3          4                      PlayerUnknown's Battlegrounds
# 4          5                                  Wii Sports Resort
# 5          6                 Pokemon Red / Green / Blue Version
# 6          7                              New Super Mario Bros.
# 9         10                                          Minecraft
# 10        11                                          Duck Hunt
# 19        20                                 Grand Theft Auto V
# 20        21                                 Grand Theft Auto V
# 22        23                                        Garry's Mod
# 26        27                      Grand Theft Auto: San Andreas
# 30        31                        Grand Theft Auto: Vice City
# ...

# %%
#groupby by count
df.groupby(df['ESRB_Rating']).count()
# Out:
#               Rank   Name  basename  Genre  Platform  Publisher  Developer  \
# ESRB_Rating
# AO              19     19        19     19        19         19         19
# E            10811  10811     10811  10811     10811      10811      10806
# E10           2897   2897      2897   2897      2897       2897       2897
# EC              54     54        54     54        54         54         54
# KA               3      3         3      3         3          3          3
# M             3314   3314      3314   3314      3314       3314       3314
# RP             368    368       368    368       368        368        368
# T             6157   6157      6157   6157      6157       6157       6157
#
#              VGChartz_Score  Critic_Score  User_Score  ...  NA_Sales  \
# ESRB_Rating                                            ...
# AO                        0             0           0  ...         0
# E                         0          2192          53  ...      5360
# ...

# %%
#total count per head column
df[["Rank", "Name", "ESRB_Rating", "Critic_Score", "PAL_Sales", "JP_Sales", "Other_Sales"]].count()
# Out:
# Rank            55792
# Name            55792
# ESRB_Rating     23623
# Critic_Score     6536
# PAL_Sales       13189
# JP_Sales         7043
# Other_Sales     15522
# dtype: int64

# %%
#Groupby rating for each head column
df_group = df[["Rank", "Name", "ESRB_Rating", "Critic_Score", "PAL_Sales", "JP_Sales", "Other_Sales"]].groupby(df["ESRB_Rating"]).sum()
df_group
# Out:
#                   Rank  Critic_Score  PAL_Sales  JP_Sales  Other_Sales
# ESRB_Rating
# AO              721291           0.0       0.00      0.00         0.00
# E            233238939       15582.4     678.65    123.69       216.15
# E10           56241803        5916.1     216.65     27.59        84.16
# EC             1231778          17.0       0.71      0.00         0.37
# KA              151477           0.0       0.00      0.00         0.00
# M             58830769        8878.9     555.89     58.61       188.49
# RP            14964862          40.1       2.24      1.97         1.03
# T            117378297       13823.7     470.13    126.34       167.61

# %%
#Group by name
df_group = df[["Name", "ESRB_Rating", "Critic_Score", "PAL_Sales", "JP_Sales", "Other_Sales"]].groupby(df["Name"]).head()
df_group
# Out:
#                                                Name ESRB_Rating  Critic_Score  \
# 0                                        Wii Sports           E           7.7
# 1                                 Super Mario Bros.         NaN          10.0
# 2                                    Mario Kart Wii           E           8.2
# 3                     PlayerUnknown's Battlegrounds         NaN           NaN
# 4                                 Wii Sports Resort           E           8.0
# 5                Pokemon Red / Green / Blue Version           E           9.4
# 6                             New Super Mario Bros.           E           9.1
# 7                                            Tetris           E           NaN
# 8                         New Super Mario Bros. Wii           E           8.6
# 9                                         Minecraft         NaN          10.0
# 10                                        Duck Hunt         NaN           NaN
# ...

# %%
dfsub[['Name', 'ESRB_Rating', 'Critic_Score','PAL_Sales', 'JP_Sales', 'Other_Sales']]
# Out:
#                                                Name ESRB_Rating  Critic_Score  \
# 0                                        Wii Sports           E           7.7
# 1                                 Super Mario Bros.         NaN          10.0
# 2                                    Mario Kart Wii           E           8.2
# 3                     PlayerUnknown's Battlegrounds         NaN           NaN
# 4                                 Wii Sports Resort           E           8.0
# 5                Pokemon Red / Green / Blue Version           E           9.4
# 6                             New Super Mario Bros.           E           9.1
# 7                                            Tetris           E           NaN
# 8                         New Super Mario Bros. Wii           E           8.6
# 9                                         Minecraft         NaN          10.0
# 10                                        Duck Hunt         NaN           NaN
# ...

# %%
dfsub[['Name','Critic_Score','PAL_Sales', 'JP_Sales', 'Other_Sales']]
# Out:
#                                                Name  Critic_Score  PAL_Sales  \
# 0                                        Wii Sports           7.7        NaN
# 1                                 Super Mario Bros.          10.0        NaN
# 2                                    Mario Kart Wii           8.2        NaN
# 3                     PlayerUnknown's Battlegrounds           NaN        NaN
# 4                                 Wii Sports Resort           8.0        NaN
# 5                Pokemon Red / Green / Blue Version           9.4        NaN
# 6                             New Super Mario Bros.           9.1        NaN
# 7                                            Tetris           NaN        NaN
# 8                         New Super Mario Bros. Wii           8.6        NaN
# 9                                         Minecraft          10.0        NaN
# 10                                        Duck Hunt           NaN        NaN
# ...
