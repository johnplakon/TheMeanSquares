# %%
#Dependencies
import urllib.request
import requests
import pandas as pd
import numpy as np
# Import BS library so we can parse HTML and XML document
from bs4 import BeautifulSoup as bs

# %%
# specify which url/web pages we are scraping
url_best_selling = "https://en.wikipedia.org/wiki/List_of_best-selling_video_games"
url_high_gross = "https://vgsales.fandom.com/wiki/List_of_highest-grossing_video_games"

# %%
# open the  best_selling url using urllib.request and put the html into variable
page = urllib.request.urlopen(url_best_selling)

# %%
# parse the HTML from our url into the BS parse tree format
best_sell_soup = bs(page, 'lxml')

# %%
# print(best_sell_soup.prettify())

# %%
# use 'find_all' function to bring back all instance of the table tag
best_sell_tables=best_sell_soup.find_all('table')
# best_sell_tables

# %%
sales_table=best_sell_soup.find('table', class_='wikitable plainrowheaders sortable')
#sales_table

# %%
# To look thru the rows, setup array to store strings
A = []
B = []
C =[]
D = []
E =[]
F = []

for row in sales_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==8:
        t_a=cells[0].findAll('a')
        A.append(t_a[0].contents[0])
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))
        F.append(cells[5].find(text=True))
        
print(F[:5])
# Out:
# ['Mojang', 'Spectrum HoloByte', 'Rockstar Games', 'Nintendo', 'PUBG Corporation']

# %%
df=pd.DataFrame(A, columns=['Title'])
df['Sales']=B
df['Platform']=C
df['Release_date']=D
df['Developer']=E
df['Publisher']=F
df
# Out:
#                              Title         Sales          Platform  \
# 0                        Minecraft   176,000,000   Multi-platform
#
# 1                           Tetris   170,000,000   Multi-platform
#
# 2               Grand Theft Auto V  110,000,000
#    Multi-platform
#
# 3                       Wii Sports   82,870,000
#                Wii
# 4    PlayerUnknown's Battlegrounds   50,000,000
#    Multi-platform
#
# 5                Super Mario Bros.   48,240,000
#    Multi-platform
#
# 6           Pokémon Red/Green/Blue   47,520,000
#    Multi-platform
#
# 7                          Wii Fit   43,800,000
#               Wii
#
# 8                   Mario Kart Wii   37,200,000
#               Wii
#
# 9                Wii Sports Resort   33,100,000
#               Wii
#
# 10           New Super Mario Bros.   30,800,000
#        Nintendo DS
# 11       New Super Mario Bros. Wii   30,260,000
#               Wii
#
# 12     The Elder Scrolls V: Skyrim   30,000,000
#    Multi-platform
#
# 13                      Diablo III   30,000,000
#    Multi-platform
#
# 14             Pokémon Gold/Silver   29,490,000
#     Game Boy Color
# 15                       Duck Hunt   28,300,000
#                NES
# 16                        Wii Play   28,020,000
#               Wii
#
# 17   Grand Theft Auto: San Andreas   27,500,000
#    Multi-platform
#
# 18                        Terraria    27,000,000   Multi-platform
#
# 19  Call of Duty: Modern Warfare 3   26,500,000
#    Multi-platform
#
# 20             Mario Kart 8/Deluxe   26,330,000
#    Multi-platform
#
# 21         Call of Duty: Black Ops   26,200,000
#    Multi-platform
#
# 22             Grand Theft Auto IV   25,000,000
#    Multi-platform
#
# 23           Red Dead Redemption 2   25,000,000
#    Multi-platform
#
# 24           Pokémon Diamond/Pearl   24,730,000
#        Nintendo DS
# 25                Pokémon Sun/Moon   24,630,000
#       Nintendo 3DS
# 26      Call of Duty: Black Ops II   24,200,000
#    Multi-platform
#
# 27                         FIFA 18   24,000,000
#    Multi-platform
#
# 28              Kinect Adventures!   24,000,000
#           Xbox 360
# 29              Sonic the Hedgehog    23,982,960   Multi-platform
#
# 30                      Nintendogs   23,960,000
#       Nintendo DS
#
# 31                   Mario Kart DS   23,600,000
#       Nintendo DS
#
# 32  Call of Duty: Modern Warfare 2   22,700,000
#    Multi-platform
#
# 33           Pokémon Ruby/Sapphire   22,540,000
#   Game Boy Advance
# 34                   Borderlands 2   22,000,000
#    Multi-platform
#
# 35               Super Mario World   20,972,500
#    Multi-platform
#
# 36                         Frogger   20,000,000
#    Multi-platform
#
# 37     Grand Theft Auto: Vice City   20,000,000
#    Multi-platform
#
# 38                        Lemmings   20,000,000
#    Multi-platform
#
# 39        The Witcher 3: Wild Hunt   20,000,000
#    Multi-platform
#
# 40                       Brain Age   19,010,000
#       Nintendo DS
#
# 41             Super Mario Bros. 3   19,000,000
#    Multi-platform
#
# 42            Call of Duty: Ghosts   19,000,000
#    Multi-platform
#
# 43                    Mario Kart 7   18,380,000
#      Nintendo 3DS
#
# 44                Super Mario Land   18,370,500
#    Multi-platform
#
# 45   Sonic & Sega All-Stars Racing    17,770,000   Multi-platform
#
# 46            Grand Theft Auto III   17,500,000
#    Multi-platform
#
# 47                  The Last of Us   17,000,000
#    Multi-platform
#
# 48                <i>Pokémon X</i>   16,400,000
#      Nintendo 3DS
#
# 49                        The Sims   16,000,000
#    Multi-platform
#
#
#           Release_date               Developer                    Publisher
# 0    November 18, 2011                  Mojang                       Mojang
# 1         June 6, 1984     Elektronorgtechnica            Spectrum HoloByte
# 2   September 17, 2013          Rockstar North               Rockstar Games
# 3    November 19, 2006            Nintendo EAD                     Nintendo
# 4    December 20, 2017        PUBG Corporation             PUBG Corporation
# 5   September 13, 1985                Nintendo                     Nintendo
# 6    February 27, 1996              Game Freak                     Nintendo
# 7     December 1, 2007            Nintendo EAD                     Nintendo
# 8       April 10, 2008            Nintendo EAD                     Nintendo
# 9        June 25, 2009            Nintendo EAD                     Nintendo
# 10        May 15, 2006            Nintendo EAD                     Nintendo
# 11   November 11, 2009            Nintendo EAD                     Nintendo
# 12   November 11, 2011   Bethesda Game Studios           Bethesda Softworks
# 13        May 16, 2012  Blizzard Entertainment       Blizzard Entertainment
# 14   November 21, 1999              Game Freak                     Nintendo
# 15      April 21, 1984           Nintendo R&D1                     Nintendo
# 16    December 2, 2006            Nintendo EAD                     Nintendo
# 17    October 26, 2004          Rockstar North               Rockstar Games
# 18        May 16, 2011                Re-Logic                     Re-Logic
# 19    November 8, 2011           Infinity Ward                   Activision
# 20        May 29, 2014            Nintendo EAD                     Nintendo
# 21    November 9, 2010                Treyarch                   Activision
# 22      April 29, 2008          Rockstar North               Rockstar Games
# 23    October 26, 2018        Rockstar Studios               Rockstar Games
# 24  September 28, 2006              Game Freak                     Nintendo
# 25   November 18, 2016              Game Freak                     Nintendo
# 26   November 12, 2012                Treyarch                   Activision
# 27  September 29, 2017               EA Canada              Electronic Arts
# 28    November 4, 2010     Good Science Studio            Microsoft Studios
# 29       June 23, 1991              Sonic Team                         Sega
# 30      April 21, 2005            Nintendo EAD                     Nintendo
# 31   November 14, 2005            Nintendo EAD                     Nintendo
# 32   November 10, 2009           Infinity Ward                   Activision
# 33   November 21, 2002              Game Freak                     Nintendo
# 34  September 18, 2012        Gearbox Software                     2K Games
# 35   November 21, 1990            Nintendo EAD                     Nintendo
# 36        June 5, 1981                  Konami                         Sega
# 37    October 27, 2002          Rockstar North               Rockstar Games
# 38   February 14, 1991              DMA Design                    Psygnosis
# 39        May 19, 2015          CD Projekt Red                   CD Projekt
# 40        May 19, 2005            Nintendo SPD                     Nintendo
# 41    October 23, 1988                Nintendo                     Nintendo
# 42    November 5, 2013           Infinity Ward                   Activision
# 43    December 1, 2011            Nintendo EAD                     Nintendo
# 44      April 21, 1989           Nintendo R&D1                     Nintendo
# 45   February 23, 2010            Sumo Digital                         Sega
# 46    October 22, 2001              DMA Design               Rockstar Games
# 47       June 14, 2013             Naughty Dog  Sony Computer Entertainment
# 48    October 12, 2013              Game Freak                     Nintendo
# 49    January 31, 2000                   Maxis              Electronic Arts

# %%
# open the  high_grossing url using urllib.request and put the html into variable
page2 = urllib.request.urlopen(url_high_gross)

# %%
# parse the HTML from our url into the BS parse tree format
high_gross_soup = bs(page2, 'lxml')

# %%
gross_table=high_gross_soup.find('table', class_='wikitable sortable')
#gross_table

# %%
# To look thru the rows, setup array to store strings
Title = []
H = []
I =[]
J = []
K =[]
Gross_revenue = []


for row in gross_table.findAll('tr'):
    cells=row.findAll('td')
#     print(cells)
    if len(cells)==7:
        g_a=cells[0].find('i')
        Title.append(g_a.text)
        
#         G.append(g_a[0].find(text=True))
#         #H.append(cells[1].find(text=True))
#         #I.append(cells[2].find(text=True))
#         #J.append(cells[3].find(text=True))
#         #K.append(cells[4].find(text=True))
        Gross_revenue.append(cells[5].text)
        
L[:5]
# Out:
# [' 16,330\n', ' 14,457\n', ' 11,854\n', ' 11,800\n', ' 10,850\n']

# %%
vz_df = pd.read_csv('C:/DataVisual/vgsales.csv')
vz_df.head()
# Out:
#     Rank                                            Name  \
# 0   5337                                            TERA
# 1   7969                Danganronpa: Trigger Happy Havoc
# 2   8513                                 Ghostbusters II
# 3   8559  Valkyria Chronicles III: Unrecorded Chronicles
# 4  15641                                  Check vs. Mate
#
#                                         basename         Genre ESRB_Rating  \
# 0                                           tera  Role-Playing           M
# 1                danganronpa-trigger-happy-havoc     Adventure         NaN
# 2                                ghostbusters-ii        Action         NaN
# 3  valkyria-chronicles-iii-unrecorded-chronicles  Role-Playing          RP
# 4                                  check-vs-mate          Misc           T
#
#   Platform Publisher            Developer  VGChartz_Score  Critic_Score  \
# 0       PC   Unknown             En Masse             NaN           NaN
# 1      PSP   Unknown                Spike             NaN           NaN
# 2     2600   Unknown            Salu Ltd.             NaN           NaN
# 3      PSP   Unknown   Sega WOW Overworks             NaN           NaN
# 4      PS3   Unknown  TopWare Interactive             NaN           NaN
#
#    User_Score  Total_Shipped  Global_Sales  NA_Sales  PAL_Sales  JP_Sales  \
# 0         NaN            NaN          0.42      0.25       0.13       NaN
# 1         NaN            NaN          0.24       NaN        NaN      0.24
# 2         NaN            NaN          0.21      0.20       0.01       NaN
# 3         NaN            NaN          0.21       NaN        NaN      0.21
# 4         NaN            NaN          0.04       NaN       0.04       NaN
#
#    Other_Sales    Year  Last_Update
# 0         0.04  1970.0          NaN
# 1          NaN  1970.0  11th Jan 18
# 2         0.00  1970.0          NaN
# 3          NaN  1970.0          NaN
# 4         0.01  1970.0          NaN

# %%
# vz_df.dtypes
vz_df_2018 = vz_df[vz_df['Year'] ==2018]
vz_df_2018.count()
# Out:
# Rank              1481
# Name              1481
# basename          1481
# Genre             1481
# ESRB_Rating        628
# Platform          1481
# Publisher         1481
# Developer         1481
# VGChartz_Score       0
# Critic_Score       135
# User_Score          57
# Total_Shipped       58
# Global_Sales       693
# NA_Sales           486
# PAL_Sales          250
# JP_Sales           308
# Other_Sales        529
# Year              1481
# Last_Update       1460
# dtype: int64

# %%
vz_df_2018.dropna(subset=['Global_Sales'])
vz_df_2018 = vz_df_2018.head(100)

# %%
# vz_df_2018

# %%
vz_df_2018=vz_df_2018[["Name", "Genre", "Platform", "Publisher", "Developer", "Global_Sales", "NA_Sales", "PAL_Sales", "JP_Sales", "Other_Sales"]]
vz_df_2018.count()
# Out:
# Name            100
# Genre           100
# Platform        100
# Publisher       100
# Developer       100
# Global_Sales    100
# NA_Sales         98
# PAL_Sales        98
# JP_Sales         55
# Other_Sales     100
# dtype: int64

# %%
vz_df_2018.fillna(0)
# Out:
#                                             Name             Genre Platform  \
# 52260                      Red Dead Redemption 2  Action-Adventure      PS4
# 52261               Call of Duty: Black Ops IIII           Shooter      PS4
# 52262                                    FIFA 19            Sports      PS4
# 52263                          God of War (2018)            Action      PS4
# 52264                      Red Dead Redemption 2  Action-Adventure     XOne
# 52265               Call of Duty: Black Ops IIII           Shooter     XOne
# 52266                      Monster Hunter: World            Action      PS4
# 52267                Pokemon: Let's Go, Pikachu!      Role-Playing       NS
# 52268                                  Far Cry 5            Action      PS4
# 52269                   Assassin's Creed Odyssey  Action-Adventure      PS4
# 52270                  Pokemon: Let's Go, Eevee!      Role-Playing       NS
# 52271                                   NBA 2K19            Sports      PS4
# 52272                              Battlefield V           Shooter      PS4
# 52273                                    FIFA 19            Sports     XOne
# 52274                              Madden NFL 19            Sports      PS4
# 52275                    Spyro Reignited Trilogy          Platform      PS4
# 52276  Dragon Quest XI: Echoes of an Elusive Age      Role-Playing      PS4
# 52277                                  Minecraft           Sandbox       NS
# 52278                            Forza Horizon 4            Racing     XOne
# 52279                                  Far Cry 5            Action     XOne
# 52280                                   NBA 2K19            Sports     XOne
# 52281                  Shadow of the Tomb Raider  Action-Adventure      PS4
# 52282                              Battlefield V           Shooter     XOne
# 52283                              Madden NFL 19            Sports     XOne
# 52284                       Dragon Ball FighterZ          Fighting      PS4
# 52285                   Assassin's Creed Odyssey  Action-Adventure     XOne
# 52286                                 Fallout 76      Role-Playing      PS4
# 52287                     Shadow of the Colossus  Action-Adventure      PS4
# 52288            Crash Bandicoot N. Sane Trilogy          Platform       NS
# 52289                            MLB The Show 18            Sports      PS4
# ...                                          ...               ...      ...
# 52330                       Dragon Ball FighterZ          Fighting       NS
# 52331                     LEGO DC Super-Villains  Action-Adventure       NS
# 52332                                     NHL 19            Sports      PS4
# 52333      Nintendo Labo: Toy-Con 03 Vehicle Kit            Racing       NS
# 52334                              Rocket League            Sports       NS
# 52335                        Firewall: Zero Hour           Shooter      PS4
# 52336                                Go Vacation              Misc       NS
# 52337                Burnout Paradise Remastered            Racing      PS4
# 52338                         Dynasty Warriors 9            Action      PS4
# 52339                           Yakuza: Kiwami 2            Action      PS4
# 52340                                     Vampyr      Role-Playing      PS4
# 52341                        Destiny 2: Forsaken           Shooter      PS4
# 52342           Taiko no Tatsujin: Drum 'n' Fun!             Music       NS
# 52343      Fist of The North Star: Lost Paradise            Action      PS4
# 52344        Nintendo Labo: Toy-Con 02 Robot Kit            Action       NS
# 52345                                Mega Man 11          Platform       NS
# 52346                             Hello Neighbor            Action      PS4
# 52347                      Sega Genesis Classics              Misc      PS4
# 52348               LEGO Harry Potter Collection            Action       NS
# 52349                                 The Crew 2            Racing     XOne
# 52350              PlayerUnknown's Battlegrounds           Shooter      PS4
# 52351                       Kirby: Battle Royale          Fighting      3DS
# 52352                     Dark Souls: Remastered      Role-Playing       NS
# 52353                       LEGO The Incredibles            Action     XOne
# 52354                       Farming Simulator 19        Simulation     XOne
# 52355                                   NBA 2K19            Sports       NS
# 52356                      My Hero One's Justice          Fighting      PS4
# 52357                             SoulCalibur VI          Fighting     XOne
# 52358                     LEGO DC Super-Villains  Action-Adventure     XOne
# 52359             Sword Art Online: Fatal Bullet      Role-Playing      PS4
#
#                                     Publisher  \
# 52260                          Rockstar Games
# 52261                              Activision
# 52262                         Electronic Arts
# 52263          Sony Interactive Entertainment
# 52264                          Rockstar Games
# 52265                              Activision
# 52266                                  Capcom
# 52267                                Nintendo
# 52268                                 Ubisoft
# 52269                                 Ubisoft
# 52270                                Nintendo
# 52271                               2K Sports
# 52272                         Electronic Arts
# 52273                         Electronic Arts
# 52274                               EA Sports
# 52275                              Activision
# 52276                             Square Enix
# 52277                                  Mojang
# 52278                       Microsoft Studios
# 52279                                 Ubisoft
# 52280                               2K Sports
# 52281                             Square Enix
# 52282                         Electronic Arts
# 52283                               EA Sports
# 52284                      Namco Bandai Games
# 52285                                 Ubisoft
# 52286                      Bethesda Softworks
# 52287          Sony Interactive Entertainment
# 52288                              Activision
# 52289          Sony Interactive Entertainment
# ...                                       ...
# 52330              Bandai Namco Entertainment
# 52331  Warner Bros. Interactive Entertainment
# 52332                               EA Sports
# 52333                                Nintendo
# 52334                               505 Games
# 52335          Sony Interactive Entertainment
# 52336                                Nintendo
# 52337                         Electronic Arts
# 52338                              Tecmo Koei
# 52339                                    Sega
# 52340                  Focus Home Interactive
# 52341                              Activision
# 52342                      Bandai Namco Games
# 52343                                    Sega
# 52344                                Nintendo
# 52345                                  Capcom
# 52346                        Gearbox Software
# 52347                                    Sega
# 52348  Warner Bros. Interactive Entertainment
# 52349                                 Ubisoft
# 52350          Sony Interactive Entertainment
# 52351                                Nintendo
# 52352              Bandai Namco Entertainment
# 52353  Warner Bros. Interactive Entertainment
# 52354                  Focus Home Interactive
# 52355                               2K Sports
# 52356              Bandai Namco Entertainment
# 52357                      Bandai Namco Games
# 52358  Warner Bros. Interactive Entertainment
# 52359                      Namco Bandai Games
#
#                               Developer  Global_Sales  NA_Sales  PAL_Sales  \
# 52260                    Rockstar Games         13.94      5.26       6.21
# 52261                          Treyarch          9.32      4.05       3.28
# 52262                         EA Sports          9.15      0.84       6.87
# 52263           SIE Santa Monica Studio          6.15      2.83       2.17
# 52264                    Rockstar Games          5.77      3.76       1.47
# 52265                          Treyarch          4.85      3.27       1.12
# 52266                            Capcom          4.67      1.03       1.06
# 52267                        Game Freak          4.57      2.16       1.24
# 52268                           Ubisoft          3.95      1.44       1.73
# 52269                    Ubisoft Quebec          3.18      1.18       1.40
# 52270                        Game Freak          2.73      1.22       0.80
# 52271                   Visual Concepts          2.63      1.69       0.44
# 52272                           EA DICE          2.22      0.80       0.93
# 52273                         EA Sports          2.22      0.56       1.50
# 52274                        EA Tiburon          2.21      1.63       0.18
# 52275                      Toys for Bob          2.17      0.75       1.07
# 52276                       Square Enix          2.04      0.29       0.22
# 52277                        4J Studios          1.89      0.69       0.56
# 52278                  Playground Games          1.84      0.74       0.95
# 52279                  Ubisoft Montreal          1.78      1.14       0.47
# 52280                   Visual Concepts          1.74      1.47       0.08
# 52281                    Eidos Montreal          1.74      0.59       0.82
# 52282                           EA DICE          1.55      1.05       0.35
# 52283                        EA Tiburon          1.51      1.33       0.02
# 52284                  Arc System Works          1.46      0.61       0.51
# 52285                    Ubisoft Quebec          1.39      0.91       0.35
# 52286             Bethesda Game Studios          1.32      0.52       0.49
# 52287                   Bluepoint Games          1.20      0.44       0.52
# 52288                      Toys for Bob          1.11      0.44       0.57
# 52289              SIE San Diego Studio          1.06      0.86       0.00
# ...                                 ...           ...       ...        ...
# 52330                  Arc System Works          0.44      0.21       0.13
# 52331                 Traveller's Tales          0.44      0.28       0.12
# 52332                         EA Canada          0.43      0.26       0.09
# 52333                      Nintendo EPD          0.41      0.16       0.15
# 52334                   Psyonix Studios          0.40      0.21       0.16
# 52335  First Contact Entertainment Inc.          0.37      0.14       0.16
# 52336              Bandai Namco Studios          0.37      0.12       0.22
# 52337             Stellar Entertainment          0.37      0.08       0.22
# 52338                       Omega Force          0.37      0.10       0.06
# 52339                              Sega          0.37      0.08       0.06
# 52340             DONTNOD Entertainment          0.37      0.12       0.19
# 52341                            Bungie          0.36      0.19       0.11
# 52342                Bandai Namco Games          0.36      0.00       0.08
# 52343                              Sega          0.36      0.09       0.05
# 52344                      Nintendo EPD          0.36      0.18       0.08
# 52345                            Capcom          0.36      0.29       0.00
# 52346                    Dynamic Pixels          0.35      0.13       0.16
# 52347                              Sega          0.35      0.08       0.21
# 52348                 Traveller's Tales          0.33      0.15       0.16
# 52349                       Ivory Tower          0.33      0.20       0.10
# 52350                  PUBG Corporation          0.33      0.13       0.15
# 52351                    HAL Laboratory          0.33      0.07       0.05
# 52352                     From Software          0.33      0.16       0.11
# 52353                 Traveller's Tales          0.32      0.19       0.10
# 52354                   Giants Software          0.32      0.19       0.09
# 52355                   Visual Concepts          0.30      0.24       0.02
# 52356                            Byking          0.30      0.16       0.05
# 52357                      Project Soul          0.30      0.26       0.01
# 52358                 Traveller's Tales          0.30      0.20       0.07
# 52359                 Dimps Corporation          0.29      0.11       0.03
#
#        JP_Sales  Other_Sales
# 52260      0.21         2.26
# 52261      0.50         1.49
# 52262      0.10         1.34
# 52263      0.13         1.02
# 52264      0.00         0.54
# 52265      0.00         0.46
# 52266      2.17         0.42
# 52267      0.82         0.34
# 52268      0.15         0.62
# 52269      0.09         0.51
# 52270      0.51         0.20
# 52271      0.03         0.47
# 52272      0.16         0.34
# 52273      0.00         0.16
# 52274      0.00         0.41
# 52275      0.00         0.35
# 52276      1.43         0.10
# 52277      0.52         0.12
# 52278      0.01         0.15
# 52279      0.00         0.17
# 52280      0.00         0.18
# 52281      0.06         0.27
# 52282      0.00         0.15
# 52283      0.00         0.16
# 52284      0.12         0.23
# 52285      0.00         0.13
# 52286      0.10         0.20
# 52287      0.05         0.19
# 52288      0.02         0.09
# 52289      0.00         0.20
# ...         ...          ...
# 52330      0.07         0.03
# 52331      0.00         0.04
# 52332      0.00         0.08
# 52333      0.06         0.03
# 52334      0.00         0.03
# 52335      0.02         0.06
# 52336      0.01         0.03
# 52337      0.01         0.06
# 52338      0.17         0.03
# 52339      0.19         0.03
# 52340      0.00         0.06
# 52341      0.00         0.06
# 52342      0.27         0.01
# 52343      0.18         0.03
# 52344      0.08         0.03
# 52345      0.03         0.03
# 52346      0.00         0.06
# 52347      0.00         0.05
# 52348      0.00         0.03
# 52349      0.00         0.03
# 52350      0.00         0.05
# 52351      0.20         0.01
# 52352      0.03         0.03
# 52353      0.00         0.03
# 52354      0.00         0.03
# 52355      0.01         0.03
# 52356      0.04         0.05
# 52357      0.00         0.03
# 52358      0.00         0.03
# 52359      0.13         0.03
#
# [100 rows x 10 columns]
